# %%
import os 
os.chdir('/data3/xusc/exp/cerberus')

from os.path import join, split, isdir,isfile
from torchvision import transforms
from dataloaders.datasets.bsds_hd5 import Mydataset
from utils import *

# %% [markdown]
# ## Check out  train val subset

# %%
train_dataset = Mydataset(root_path='data/BSDS-RIND/BSDS-RIND/Augmentation/', split='trainval', crop_size=320)

# %%
def normalize(map):
    
    return (map - map.min())/ (map.max()-map.min())
to_imger = transforms.ToPILImage()
for (image, label ) in train_dataset:
    print(image.shape, label.shape)
    
    
    
    image = to_imger(normalize(image))
    
    
    
    break
# Out:
# torch.Size([3, 320, 320]) torch.Size([5, 320, 320])

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=320x320>

# %%
for idx in range(5):
    show_imgs([label[idx,:,:]],[1])

# %% [markdown]
# ## check out the test subset

# %%
test_dataset = Mydataset(root_path='data/BSDS-RIND/BSDS-RIND/Augmentation/', split='test', crop_size=320)
for img in test_dataset:
    img = to_imger(normalize(img))
    break

# %%
# Out:
# torch.Size([3, 321, 481])

# %%
import torch
import numpy as np

from PIL import Image



def load_mat_gt(data_path):
    gt  = load_mat(data_path)
    
    return gt['groundTruth'][0,0]['Boundaries'][0,0]
    




class MydatasetTest(torch.utils.data.Dataset):

    def __init__(self,root_path='....../Augmentation/'):
        list_file = os.path.join(root_path, 'test.lst')
        self.data_root = root_path
        
        

        self.images_path = np.loadtxt(list_file,dtype=np.str0)
        
#         with open(list_file, 'r') as f:
#             lines = f.readlines()
#         lines = [line.strip() for line in lines]
#         self.images_path = lines
        
        self.images_name = []
        
        for path in self.images_path:
            folder, filename = os.path.split(path)
            name, ext = os.path.splitext(filename)
            self.images_name.append(name)
        
        
        #* preprocesser for image
        normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        self.trans = transforms.Compose([
                             transforms.ToTensor(),
                             normalize])  
        
        """
        including DNRI, depth, normal, reflectance, illumination 
        
        """
    def getitem_label(self,idx):
        
        task_list = ['all_edges','depth','normal','reflectance','illumination']
        print(self.images_name[idx])
        gt_list = []
        for task in task_list:
            print(task)
            gt_list.append(load_mat_gt(join(self.data_root,'../../testgt/%s'%(task),self.images_name[idx]+'.mat')))
            
        return gt_list
        

    def __len__(self):
        return len(self.images_path)


    def __getitem__(self, idx):
        img = Image.open(os.path.join(self.images_path[idx])).convert('RGB')
        img_tensor = self.trans(img)
        return img_tensor

# %%
test_dataset = MydatasetTest(root_path='data/BSDS-RIND/BSDS-RIND/Augmentation/')
for img in test_dataset:
    img = to_imger(normalize(img))
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_134850/3009095869.py in <module>
# ----> 1 test_dataset = MydatasetTest(root_path='data/BSDS-RIND/BSDS-RIND/Augmentation/')
#       2 for img in test_dataset:
#       3     img = to_imger(normalize(img))
#       4     break
#
# /tmp/ipykernel_134850/3376146449.py in __init__(self, root_path)
#      18
#      19     def __init__(self,root_path='....../Augmentation/'):
# ---> 20         list_file = os.path.join(root_path, 'test.lst')
#      21         self.data_root = root_path
#      22
#
# NameError: name 'os' is not defined

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=481x321>

# %%
label_list = test_dataset.getitem_label(0)
len(label_list), label_list[0].shape
# Out:
# 106005
# all_edges
# depth
# normal
# reflectance
# illumination
# (5, (321, 481))

# %%
# Out:
# (5, (321, 481))

# %%
for l in label_list:
    show_imgs([l],[1])

# %%
# ge = label_list[1:].copy()
# ge = [x[...,None] for x in ge]
# ge = np.concatenate(ge,axis=-1)

# %%
def __and(array_list,dim=-1):
    
    
    
    pass
__and(label_list[1:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_118471/600990960.py in <module>
# ----> 1 np.maximum(ge,axis=-1)
#
# TypeError: maximum() takes from 2 to 3 positional arguments but 1 were given

# %%
label_list[0].shape
